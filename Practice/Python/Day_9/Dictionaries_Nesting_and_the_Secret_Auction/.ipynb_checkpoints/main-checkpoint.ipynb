# %% [markdown]
# # Dictionary

# %%
colors = {
    "Apple": "Red",
    "Pear": "Green",
    "Banana": "Yellow"
}

# %%
print(colors["Apple"])
# Out:
# Red

# %%
colors["Grapes"] = "Purple"

# %%
print(colors)
# Out:
# {'Apple': 'Red', 'Pear': 'Green', 'Banana': 'Yellow', 'Grapes': 'Purple'}

# %%
empty = {}

# %%
# colors = {}
# print(colors)

# %%
print(colors["Banana"])
# Out:
# Yellow

# %%
colors["Banana"] = "Lemon Yellow"

# %%
print(colors)
# Out:
# {'Apple': 'Red', 'Pear': 'Green', 'Banana': 'Lemon Yellow', 'Grapes': 'Purple'}

# %%
for key in colors:
    print(key)
# Out:
# Apple
# Pear
# Banana
# Grapes

# %%
capitals = {
    "India": "New Delhi",
    "Spain": "Madrid", 
    "France": "Paris",
    "United Kingdom": "London",
    "United States of America": ["New York", "Los Angeles", "San Francisco", "Detroit"],
    "Australia": ["Perth", "Melbourne", "Sydney", "Canberra"]
}

# %%
print(capitals["Australia"][2])
# Out:
# Sydney

# %%
nested_list = ["a", "b", ["c", "d"]]

# %%
print(nested_list[-1][1])
# Out:
# d

# %%
travel_log = {
    "United Kingdom": {
        "cities_visited": ["London", "Manchester", "Liverpool"],
        "total_visits": 1
    },
    "Australia": {
        "cities_visited": ["Sydney", "Melbourne", "Perth", "Canberra"],
        "total_visits": 1
    },
}

# %%
print(travel_log["Australia"]["cities_visited"][0])
# Out:
# Sydney
