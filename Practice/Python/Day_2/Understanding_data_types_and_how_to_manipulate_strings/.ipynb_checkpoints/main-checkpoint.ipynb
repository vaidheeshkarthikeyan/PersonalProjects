# %% [markdown]
# # Data Types

# %% [markdown]
# 1. Strings
# 2. Integers
# 3. Floats
# 4. Booleans

# %%
print("123" + "345")
# Out:
# 123345

# %%
print(123_456_789)
# Out:
# 123456789

# %%
print(len(str(345)))
# Out:
# 3

# %% [markdown]
# TypeError

# %%
print(type(123_456))
# Out:
# <class 'int'>

# %%
print(type("Hi"))
print(type(25))
print(type(25.234))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # Type Conversion

# %%
print(int("12345"))
# Out:
# 12345

# %%
name = input("Enter your name:\n")
print(type(name))
length = len(name)
print(type(length))
print("\nNumber of letters in your name: " + str(length))
# Out:
# Enter your name:
#  Vaidheesh
# <class 'str'>
# <class 'int'>
#
# Number of letters in your name: 9

# %% [markdown]
# # Mathematical Operations

# %%
print(123 + 456)
print(7 - 3)
print(3 * 2)
print(5 / 3)
print(5 // 3)
print(2 ** 3)
# Out:
# 579
# 4
# 6
# 1.6666666666666667
# 1
# 8

# %% [markdown]
# PEMDAS
#
# Parenthesis, Exponentiation, Multiplication, Division, Addition, Subtraction

# %%
print(3 * 3 + 3 / 3 - 3)
# Out:
# 7.0

# %%
bmi = 84 / 1.65 ** 2
print(round(bmi, 2))
# Out:
# 30.85

# %%
score = 0
score += 1
print(score)
# Out:
# 1

# %%
print(f"Your score is {score}")
# Out:
# Your score is 1
