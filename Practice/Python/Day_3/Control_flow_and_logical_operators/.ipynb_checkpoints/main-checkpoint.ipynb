# %%
height = int(input("Enter your height in cm:\n"))

if height >= 120:
    print("You are eligible to ride the roller coaster")
else:
    print("You are not eligible to ride the roller coaster")
# Out:
# Enter your height in cm:
#  120
# You are eligible to ride the roller coaster

# %% [markdown]
# # Comparison Operators

# %% [markdown]
# These are the comparison operators: >, <, >=, <=, ==, !=

# %% [markdown]
# # Modulo operator: %
#
# It gives the remainder when two numbers are divided

# %%
print(10 % 3)
# Out:
# 1

# %%
number = int(input("Enter a number:\n"))

if(number % 2 == 0):
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:
#  5
# Odd

# %%
number = int(input("Enter a number:\n"))

print(number % 2 == 0)
# Out:
# Enter a number:
#  5
# False

# %%
height = int(input("Enter your height in cm:\n"))

if height >= 120:
    print("You are eligible to ride the roller coaster")
    age = int(input("Enter your age:\n"))
    if age >= 18:
        bill = 12
        print("Adult Ticket: $12.")
    elif age >= 12 and age < 18:
        bill = 7
        print("Youth Ticket: $7.")
    else:
        bill = 5
        print("Child Ticket: $5.")

    wants_photo = input("Do you want to take photos? Type 'y' for yes and 'n' for no:\n")

    if wants_photo == 'y':
        bill += 3
        
    print(f"Total bill: ${bill}")
else:
    print("You are not eligible to ride the roller coaster")
# Out:
# Enter your height in cm:
#  169
# You are eligible to ride the roller coaster
# Enter your age:
#  25
# Adult Ticket: $12.
# Do you want to take photos? Type 'y' for yes and 'n' for no:
#  n
# Total bill: $12

# %%
print("Welcome to Python Pizzaz")
size = input("Enter the size of your pizza S, M or L:\n")
pepperoni = input("Do you want to add pepperoni on your pizza? Y or N:\n")
extra_cheese = input("Do you wish for extra cheese on your pizza? Y or N:\n")

bill = 0

if size == 'S':
    bill += 15
    if pepperoni == 'Y':
        bill += 2
    if extra_cheese == 'Y':
        bill += 1
elif size == 'M':
    bill += 20
    if pepperoni == 'Y':
        bill += 3
    if extra_cheese == 'Y':
        bill += 1
elif size == 'L':
    bill += 25
    if pepperoni == 'Y':
        bill += 3
    if extra_cheese == 'Y':
        bill += 1
else:
    print("Can't accept the input value")

print(f'Your total bill: ${bill}')
# Out:
# Welcome to Python Pizzaz
# Enter the size of your pizza S, M or L:
#  M
# Do you want to add pepperoni on your pizza? Y or N:
#  Y
# Do you wish for extra cheese on your pizza? Y or N:
#  Y
# Your total bill: $24

# %% [markdown]
# # Logical Operators
#
# These are the logical operators: and, or, not
