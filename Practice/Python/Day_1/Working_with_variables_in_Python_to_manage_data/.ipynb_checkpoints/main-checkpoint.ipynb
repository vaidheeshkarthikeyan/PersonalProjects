# %% [markdown]
# # Printing to console

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # String Manipulation

# %%
print("Hello, world!\nHello, world!")
# Out:
# Hello, world!
# Hello, world!

# %%
print("Hello" + " " + "Vaidheesh")
# Out:
# Hello Vaidheesh

# %% [markdown]
# 1. SyntaxError
# 2. IndentationError
# 3. NameError

# %% [markdown]
# # input() function

# %%
input("What is your name?")
# Out:
# What is your name? Vaidheesh
# 'Vaidheesh'

# %%
print("Hello " + input("What is your name?") + "!")
# Out:
# What is your name? Vaidheesh
# Hello Vaidheesh!

# %%
# - This is a comment and it is completely ignored by the computer

# %% [markdown]
# # Variables

# %%
name = input("Enter your name: ")
# Out:
# Enter your name:  Vaidheesh

# %%
print(name)
# Out:
# Vaidheesh

# %%
print("Hello " + name + "!")
# Out:
# Hello Vaidheesh!

# %%
print(len(name))
# Out:
# 9

# %%
name_length = len(name)
print(name_length)
# Out:
# 9

# %% [markdown]
# # Variable Naming rules

# %% [markdown]
# 1. Make sure your variable names are descriptive
# 2. Don't have spaces between words
# 3. Don't start with numbers
# 4. Don't use special words like print or input
