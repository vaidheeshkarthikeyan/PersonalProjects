# %%
import pandas as pd
import numpy as np
import re
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import transformers
from transformers import pipeline

# %%
data = pd.read_csv("book_reviews_sample.csv")

# %%
data.head()
# Out:
#    index                                         reviewText  rating
# 0  11494  Clean and funny. A bit busy with all the diffe...       3
# 1    984  Alex a sexy hot cop and the PhD candidate. Wha...       4
# 2   1463  Good thing that this is a free story. I read i...       1
# 3  10342  Action, action, action! Equipment keeps gettin...       4
# 4   5256  this was hands down the worse book i have ever...       1

# %%
data["reviewText_clean"] = data["reviewText"].str.lower()

# %%
data["reviewText_clean"] = data["reviewText_clean"].apply(lambda x: re.sub(r"[^\w\s]", "", x))

# %%
data.head()
# Out:
#    index                                         reviewText  rating  \
# 0  11494  Clean and funny. A bit busy with all the diffe...       3
# 1    984  Alex a sexy hot cop and the PhD candidate. Wha...       4
# 2   1463  Good thing that this is a free story. I read i...       1
# 3  10342  Action, action, action! Equipment keeps gettin...       4
# 4   5256  this was hands down the worse book i have ever...       1
#
#                                     reviewText_clean
# 0  clean and funny a bit busy with all the differ...
# 1  alex a sexy hot cop and the phd candidate what...
# 2  good thing that this is a free story i read it...
# 3  action action action equipment keeps getting b...
# 4  this was hands down the worse book i have ever...

# %%
vader_sentiment = SentimentIntensityAnalyzer()

# %%
data["vader_sentiment_scores"] = data["reviewText_clean"].apply(lambda x: vader_sentiment.polarity_scores(x)["compound"])

# %%
data.head()
# Out:
#    index                                         reviewText  rating  \
# 0  11494  Clean and funny. A bit busy with all the diffe...       3
# 1    984  Alex a sexy hot cop and the PhD candidate. Wha...       4
# 2   1463  Good thing that this is a free story. I read i...       1
# 3  10342  Action, action, action! Equipment keeps gettin...       4
# 4   5256  this was hands down the worse book i have ever...       1
#
#                                     reviewText_clean  vader_sentiment_scores
# 0  clean and funny a bit busy with all the differ...                  0.7684
# 1  alex a sexy hot cop and the phd candidate what...                  0.9325
# 2  good thing that this is a free story i read it...                  0.6740
# 3  action action action equipment keeps getting b...                  0.6652
# 4  this was hands down the worse book i have ever...                 -0.4767

# %%
bins = [-1, -0.1, 0.1, 1]
names = ["negative", "neutral", "postiive"]

# %%
data["vader_sentiment_score_label"] = pd.cut(data["vader_sentiment_scores"], bins, labels=names)

# %%
data.head()
# Out:
#    index                                         reviewText  rating  \
# 0  11494  Clean and funny. A bit busy with all the diffe...       3
# 1    984  Alex a sexy hot cop and the PhD candidate. Wha...       4
# 2   1463  Good thing that this is a free story. I read i...       1
# 3  10342  Action, action, action! Equipment keeps gettin...       4
# 4   5256  this was hands down the worse book i have ever...       1
#
#                                     reviewText_clean  vader_sentiment_scores  \
# 0  clean and funny a bit busy with all the differ...                  0.7684
# 1  alex a sexy hot cop and the phd candidate what...                  0.9325
# 2  good thing that this is a free story i read it...                  0.6740
# 3  action action action equipment keeps getting b...                  0.6652
# 4  this was hands down the worse book i have ever...                 -0.4767
#
#   vader_sentiment_score_label
# 0                    postiive
# 1                    postiive
# ...

# %%
data["vader_sentiment_score_label"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='vader_sentiment_score_label'>

# %%
transformer_pipeline = pipeline("sentiment-analysis")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
transformer_labels = []

for review in data["reviewText_clean"].values:
    sentiment_list = transformer_pipeline(review)
    sentiment_label = [sentiment["label"] for sentiment in sentiment_list]
    transformer_labels.append(sentiment_label)

# %%
data["transformer_sentiment_label"] = transformer_labels

# %%
data["transformer_sentiment_label"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='transformer_sentiment_label'>
