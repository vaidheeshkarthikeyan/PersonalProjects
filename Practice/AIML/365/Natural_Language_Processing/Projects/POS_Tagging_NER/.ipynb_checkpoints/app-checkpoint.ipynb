# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
import re
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Loading data

# %%
data = pd.read_csv("bbc_news.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0   6684                              Can I refuse to work?
# 1           1   9267  'Liz Truss the Brief?' World reacts to UK poli...
# 2           2   7387  Rationing energy is nothing new for off-grid c...
# 3           3    767  The hunt for superyachts of sanctioned Russian...
# 4           4   3712  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                          pubDate  \
# 0  Wed, 10 Aug 2022 15:46:18 GMT
# 1  Mon, 17 Oct 2022 11:35:12 GMT
# 2  Wed, 31 Aug 2022 05:20:18 GMT
# 3  Tue, 22 Mar 2022 14:37:01 GMT
# 4  Wed, 01 Jun 2022 23:17:33 GMT
#
#                                                 guid  \
# 0       https://www.bbc.co.uk/news/business-62147992
# 1          https://www.bbc.co.uk/news/world-63285480
# 2  https://www.bbc.co.uk/news/uk-scotland-highlan...
# 3                https://www.bbc.co.uk/news/60739336
# 4             https://www.bbc.co.uk/news/uk-61660128
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   index        1000 non-null   int64
#  2   title        1000 non-null   str
#  3   pubDate      1000 non-null   str
#  4   guid         1000 non-null   str
#  5   link         1000 non-null   str
#  6   description  1000 non-null   str
# dtypes: int64(2), str(5)
# memory usage: 54.8 KB

# %%
titles = pd.DataFrame(data["title"])
titles.head()
# Out:
#                                                title
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# ## Lowercasing the text

# %%
titles["title_lowercase"] = titles["title"].str.lower()
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                      title_lowercase
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...

# %% [markdown]
# ## Removing Stopwords

# %%
en_stopwords = stopwords.words('english')
titles["title_with_no_stopwords"] = titles["title_lowercase"].apply(lambda x: " ".join([word for word in x.split() if word not in en_stopwords]))
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                      title_lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                              title_with_no_stopwords
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds

# %% [markdown]
# ## Removing punctuations

# %%
titles["title_with_no_punc"] = titles["title_with_no_stopwords"].apply(lambda x: re.sub(r"[^\w\s]", "", x))
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                      title_lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                              title_with_no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# ...

# %% [markdown]
# ## Tokenizing the text

# %%
titles["tokens_raw"] = titles["title"].apply(lambda x: word_tokenize(x))
titles["tokens_clean"] = titles["title_with_no_punc"].apply(lambda x: word_tokenize(x))

# %% [markdown]
# ## Lemmatizing the Text

# %%
lm = WordNetLemmatizer()
titles["lemmatized_tokens_clean"] = titles["tokens_clean"].apply(lambda tokens: [lm.lemmatize(token) for token in tokens])
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                      title_lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                              title_with_no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# ...

# %%
tokens_raw_list = sum(titles["tokens_raw"], [])
tokens_clean_list = sum(titles["lemmatized_tokens_clean"], [])

# %% [markdown]
# # POS Tagging

# %%
nlp = spacy.load('en_core_web_sm')

# %%
spacy_doc = nlp(' '.join(tokens_raw_list))

# %%
pos_df = pd.DataFrame(columns=["token", "pos_tag"])

for token in spacy_doc:
    pos_df = pd.concat([pos_df,
                        pd.DataFrame.from_records([{"token":token.text, "pos_tag":token.pos_}])],
                       ignore_index=True)

# %%
pos_df_count = pos_df.groupby(["token", "pos_tag"]).size().reset_index(name="count").sort_values(by="count", ascending=False)

# %%
pos_df_count.head(10)
# Out:
#      token pos_tag  count
# 93       :   PUNCT    543
# 6        '   PUNCT    307
# 2893    in     ADP    187
# 4078    to    PART    176
# 3264    of     ADP    172
# 20       -   PUNCT    166
# 4039   the     DET    163
# 1852   and   CCONJ    147
# 13      's    PART    143
# 95       ?   PUNCT    130

# %%
nouns = pos_df_count[pos_df_count["pos_tag"] == "NOUN"][:10]
nouns
# Out:
#        token pos_tag  count
# 4263     war    NOUN     35
# 3548  record    NOUN     15
# 4312     win    NOUN     15
# 4352    year    NOUN     14
# 3412  police    NOUN     14
# 4005     tax    NOUN     13
# 3057  living    NOUN     13
# 3364  people    NOUN     12
# 2322     day    NOUN     12
# 2565    fans    NOUN     11

# %%
verbs = pos_df_count[pos_df_count["pos_tag"] == "VERB"][:10]
verbs
# Out:
#       token pos_tag  count
# 3683   says    VERB     30
# 2666  found    VERB     13
# 4313    win    VERB     11
# 4320   wins    VERB     10
# 2709    get    VERB      9
# 2384   dies    VERB      9
# 3104   make    VERB      8
# 3741    set    VERB      8
# 3986   take    VERB      8
# 3682    say    VERB      8

# %% [markdown]
# # NER

# %%
ner_df = pd.DataFrame(columns=["token", "ner_tag"])

for token in spacy_doc.ents:
    if pd.isna(token.label_) is False:
        ner_df = pd.concat([ner_df,
                            pd.DataFrame.from_records(
                                [{"token": token.text,
                                  "ner_tag": token.label_}])],
                           ignore_index=True)

# %%
ner_df.head()
# Out:
#          token   ner_tag
# 0    Liz Truss    PERSON
# 1           UK       GPE
# 2    Rationing   PRODUCT
# 3  superyachts  CARDINAL
# 4      Russian      NORP

# %%
ner_df_count = ner_df.groupby(["token", "ner_tag"]).size().reset_index(name="count").sort_values(by="count", ascending=False)

# %%
ner_df_count.head()
# Out:
#        token ner_tag  count
# 965  Ukraine     GPE     47
# 955       UK     GPE     36
# 329  England     GPE     32
# 819  Russian    NORP     20
# 957       US     GPE     19
